# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Loading the datasets

# %%
df = pd.read_csv('HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# ### Data Cleaning

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.drop('B', axis=1, inplace=True)

# %%
df.shape
# Out:
# (506, 13)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4    NaN  36.2

# %% [markdown]
# #### finding duplicate or null values:

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df['CRIM'].fillna(df['CRIM'].median(), inplace=True)
df['ZN'].fillna(df['ZN'].mean(), inplace=True)
df['INDUS'].fillna(df['INDUS'].mean(), inplace=True)
df['CHAS'].fillna(df['CHAS'].median(), inplace=True)
df['AGE'].fillna(df['AGE'].median(), inplace=True)
df['LSTAT'].fillna(df['LSTAT'].median(), inplace=True)
# Out:
# /tmp/ipykernel_14752/3691067198.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CRIM'].fillna(df['CRIM'].median(), inplace=True)
# /tmp/ipykernel_14752/3691067198.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df_cleaned = df
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 51.5 KB

# %%
df_cleaned.describe().T
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     506.0    3.479140    8.570832    0.00632    0.083235    0.253715
# ZN       506.0   11.211934   22.921051    0.00000    0.000000    0.000000
# INDUS    506.0   11.083992    6.699165    0.46000    5.190000    9.900000
# CHAS     506.0    0.067194    0.250605    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      506.0   68.845850   27.486962    2.90000   45.925000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# LSTAT    506.0   12.664625    7.017219    1.73000    7.230000   11.430000
# ...

# %%
columns = df_cleaned.columns
print(columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df_cleaned.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.185890  0.392063 -0.055585  0.410971 -0.220045  0.343427
# ZN      -0.185890  1.000000 -0.513336 -0.034471 -0.502287  0.316550 -0.541719
# INDUS    0.392063 -0.513336  1.000000  0.054172  0.740965 -0.381457  0.616917
# CHAS    -0.055585 -0.034471  0.054172  1.000000  0.070867  0.106797  0.074984
# NOX      0.410971 -0.502287  0.740965  0.070867  1.000000 -0.302188  0.711864
# RM      -0.220045  0.316550 -0.381457  0.106797 -0.302188  1.000000 -0.239518
# AGE      0.343427 -0.541719  0.616917  0.074984  0.711864 -0.239518  1.000000
# DIS     -0.366025  0.638388 -0.699639 -0.092318 -0.769230  0.205246 -0.724354
# RAD      0.601224 -0.306316  0.593176 -0.003339  0.611441 -0.209847  0.447088
# TAX      0.560469 -0.308334  0.716062 -0.035822  0.668023 -0.292048  0.498408
# PTRATIO  0.277964 -0.403085  0.384806 -0.109451  0.188933 -0.355501  0.261826
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_cleaned.corr(),annot=True)
# Out:
# <Axes: >

# %%
for col in df_cleaned.columns:
    plt.figure(figsize=(6,4))
    sns.histplot(df_cleaned[col],kde=True)

# %%
sns.pairplot(df_cleaned)

# %%
df_cleaned['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# #### Price vs Crime rate:

# %%
plt.figure(figsize=(6,4))
plt.scatter(df_cleaned['CRIM'],df_cleaned['MEDV'])
plt.xlabel('Crime rate')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# #### Price vs land zoned for large lots:

# %%
plt.figure(figsize=(6,4))
plt.scatter(df_cleaned['ZN'],df_cleaned['MEDV'])
plt.xlabel('land zoned for large lots (%)')
plt.ylabel('Price ($K)')
# Out:
# Text(0, 0.5, 'Price ($K)')

# %% [markdown]
# #### Price vs Distance to employment centers

# %%
plt.figure(figsize=(6,4))
plt.scatter(df_cleaned['DIS'],df_cleaned['MEDV'])
plt.xlabel('Distance to employment centers')
plt.ylabel('Price ($K)')
# Out:
# Text(0, 0.5, 'Price ($K)')

# %% [markdown]
# #### Price vs lower-status population

# %%
plt.figure(figsize=(6,4))
plt.scatter(df_cleaned['LSTAT'],df_cleaned['MEDV'])
plt.xlabel('lower-status population')
plt.ylabel('Price ($K)')
# Out:
# Text(0, 0.5, 'Price ($K)')

# %%
sns.regplot(df_cleaned,x='LSTAT',y='MEDV')
# Out:
# <Axes: xlabel='LSTAT', ylabel='MEDV'>

# %% [markdown]
# #### Price vs rooms per dwelling

# %%
plt.figure(figsize=(6,4))
plt.scatter(df_cleaned['RM'],df_cleaned['MEDV'])
plt.xlabel('rooms per dwelling')
plt.ylabel('Price ($K)')
# Out:
# Text(0, 0.5, 'Price ($K)')

# %%
sns.regplot(df_cleaned,x='RM',y='MEDV')
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ### Preparing dataset for Model Training

# %%
df_cleaned.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4  11.43  36.2

# %%
X = df_cleaned.drop('MEDV',axis=1)
y = df_cleaned.iloc[:,-1]
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT
# 0   4.98
# 1   9.14
# 2   4.03
# 3   2.94
# 4  11.43

# %%
X.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'LSTAT'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X,y,test_size=0.35, random_state=29)

# %%
X_train
# Out:
#           CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 389   8.151740   0.0  18.10   0.0  0.700  5.390   98.9  1.7281   24  666
# 391   5.293050   0.0  18.10   0.0  0.700  6.051   82.5  2.1678   24  666
# 2     0.027290   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242
# 322   0.351140   0.0   7.38   0.0  0.493  6.041   49.9  4.7211    5  287
# 192   0.253715  45.0   3.44   0.0  0.437  7.178   26.3  6.4798    5  398
# ..         ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 296   0.053720   0.0  13.92   0.0  0.437  6.549   51.0  5.9604    4  289
# 34    1.612820   0.0   8.14   0.0  0.538  6.096   96.9  3.7598    4  307
# 236   0.253715   0.0   6.20   1.0  0.507  6.631   76.5  4.1480    8  307
# 371   9.232300   0.0  18.10   0.0  0.631  6.216  100.0  1.1691   24  666
# 469  13.075100   0.0  18.10   0.0  0.580  5.713   56.7  2.8237   24  666
#
#      PTRATIO  LSTAT
# 389     20.2  20.85
# 391     20.2  18.76
# 2       17.8   4.03
# ...

# %%
y_train
# Out:
# 389    11.5
# 391    23.2
# 2      34.7
# 322    20.4
# 192    36.4
#        ...
# 296    27.1
# 34     13.5
# 236    25.1
# 371    50.0
# 469    20.1
# Name: MEDV, Length: 328, dtype: float64

# %%
y_test
# Out:
# 185    29.6
# 225    50.0
# 64     33.0
# 19     18.2
# 128    18.0
#        ...
# 46     20.0
# 202    42.3
# 420    16.7
# 135    18.1
# 269    20.7
# Name: MEDV, Length: 178, dtype: float64

# %%
y_train
# Out:
# 389    11.5
# 391    23.2
# 2      34.7
# 322    20.4
# 192    36.4
#        ...
# 296    27.1
# 34     13.5
# 236    25.1
# 371    50.0
# 469    20.1
# Name: MEDV, Length: 328, dtype: float64

# %% [markdown]
# ### Standardizing the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-0.90951049  0.74926388 -0.49281572  1.01316488 -1.78161222  2.52879757
#  -0.41780096 -2.9099111   2.10839884 -1.81853741 -1.98010166 -3.55965306]

# %% [markdown]
# #### Prediction with test data

# %%
reg_pred = regression.predict(X_test)
reg_pred
# Out:
# array([25.12662408, 39.20647457, 23.67477077, 18.57797393, 17.32973521,
#        18.8114249 , 28.33202763, 32.03493527, 16.25500716,  4.53314192,
#        41.19832328, 25.12047113, 35.65930595, 15.20858761, 22.50269225,
#        28.21537402, 22.73633986, 25.82955687, 19.43311035, 20.69567515,
#        35.25034884, 21.24732526, 19.38727154, 20.12990332, 32.77707293,
#        21.80719138, 34.59271091, 25.92772616, 29.485277  , 33.04164953,
#        33.25974395, 26.45217422, 16.81790543, 24.69735937, 15.27727658,
#         7.35194611, 23.68575087,  5.85979226, 11.83131351, 20.87856633,
#        29.09482618, 22.41428543, 30.27388793, 14.22426074,  2.23887125,
#        17.59715449, 17.38210244, 39.29554212, 18.08887255, 17.79666741,
#        27.4716454 , 17.91039896, 21.87882275, 17.89802545, 20.1736533 ,
#        13.12978305, 25.35124902, 20.98295171, 16.74244185, 18.56125426,
#        29.10940435, 14.84309003, 25.29219492, 22.34760057, 21.00469996,
# ...

# %% [markdown]
# #### Prediction plot

# %%
plt.scatter(y_test,reg_pred)

# %% [markdown]
# ### Residual errors

# %%
residuals = y_test - reg_pred
residuals
# Out:
# 185     4.473376
# 225    10.793525
# 64      9.325229
# 19     -0.377974
# 128     0.670265
#          ...
# 46     -0.901810
# 202     5.238351
# 420    -1.552869
# 135     2.425158
# 269    -6.336545
# Name: MEDV, Length: 178, dtype: float64

# %%
sns.displot(residuals,kde=True)

# %% [markdown]
# ### Scatter plot wrt predictions and residuals

# %%
#uniform distribution
plt.scatter(reg_pred,residuals)

# %% [markdown]
# ### Performance metrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))

print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 3.0703236454561433
# 17.070209805130276
# 4.131611042333278

# %% [markdown]
# #### R2 and adjusted R2

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
print("R2 score: ",score)

# Adjusted R2 score:
AR2 = 1- (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("Adjusted R2 score: ",AR2)
# Out:
# R2 score:  0.7860093637268327
# Adjusted R2 score:  0.7704464083615115

# %% [markdown]
# ### Predicting new Data

# %%
new_data = scaler.transform([[0.00632, 18.0, 2.31, 0.0, 0.538, 6.575, 65.2, 4.0900, 1, 296, 15.3, 4.98]])

regression.predict(new_data)
# Out:
# /home/supriyogiri/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.37108122])

# %% [markdown]
# ### Pickling

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))
pickled_model
# Out:
# LinearRegression()

# %%
data = scaler.transform([[0.02729,0.0,7.07,0.0,0.469,7.185,61.1,4.9671,2,242,17.8,4.03]])
pickled_model.predict(data)
# Out:
# /home/supriyogiri/.local/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.66532362])
